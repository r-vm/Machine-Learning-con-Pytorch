# %% [markdown]
# <a href="https://colab.research.google.com/github/r-vm/Machine-Learning-con-Pytorch/blob/main/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
edad= 28
print(f"La edad es: {edad}")
# Out:
# La edad es: 28
